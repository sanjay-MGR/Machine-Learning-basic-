# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjay-MGR/Machine-Learning-basic-/blob/main/Naiveybayes_and_SVM(revision_).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import laiberies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loaddataset
data = sns.load_dataset('tips')

# %%
data.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
df = data[['total_bill','tip','sex']]

# %%
#split data into x and y
x = df.drop('sex',axis=1)
y = df['sex']

# %%
df.head(2)
# Out:
#    total_bill   tip     sex
# 0       16.99  1.01  Female
# 1       10.34  1.66    Male

# %%
df.isna().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# dtype: int64

# %%
#import GusianNb from naivybais
from sklearn.naive_bayes import GaussianNB

# %%
#import logistic regression
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# build model
modelg = GaussianNB()
modelL = LogisticRegression()

# %%
#fit the model
modelg.fit(x,y)
# Out:
# GaussianNB()

# %%
modelL.fit(x,y)
# Out:
# LogisticRegression()

# %%
#predict the value
y_predG = modelg.predict(x)
y_predG
# Out:
# array(['Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Female', 'Female', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male',
# ...

# %%
y_predL = modelL.predict(x)
y_predL
# Out:
# array(['Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
# ...

# %%
# check accuracy
acs_g = accuracy_score(y,y_predG)
acs_g
# Out:
# 0.6434426229508197

# %%
acs_l = accuracy_score(y,y_predL)
acs_l
# Out:
# 0.6475409836065574

# %%
# check the data
df.shape
# Out:
# (244, 3)

# %%
df.sex.value_counts() # the data is imbalance so we need to balance it for the better result
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
#
female = df[df['sex']=='Female']
male = df[df['sex']=='Male']

# %%
#mutiply male by 2 times and female by 4 times
for x in range(1):
  df = pd.concat([df,male])

# %%
df.sex.value_counts()
# Out:
# sex
# Male      314
# Female     87
# Name: count, dtype: int64

# %%
for x in range(3):
  df = pd.concat([df,female])

# %%
X = df.drop('sex',axis = 1)

# %%
Y = df['sex']

# %%
df.sex.value_counts() # its sims like data is balance now then we train model again and predict again
# Out:
# sex
# Female    348
# Male      314
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# dtype: int64

# %%
# New model
model_newg = GaussianNB()
model_newl = LogisticRegression()

# %%
#fit the model
model_newg.fit(X,Y)
# Out:
# GaussianNB()

# %%
model_newl.fit(X,Y)
# Out:
# LogisticRegression()

# %%
#predict the value
y_predg = model_newg.predict(X)
y_predg
# Out:
# array(['Female', 'Female', 'Female', 'Female', 'Female', 'Male', 'Female',
#        'Female', 'Female', 'Female', 'Female', 'Male', 'Female', 'Female',
#        'Female', 'Female', 'Female', 'Female', 'Female', 'Female',
#        'Female', 'Female', 'Female', 'Male', 'Female', 'Female', 'Female',
#        'Female', 'Male', 'Female', 'Female', 'Female', 'Female', 'Female',
#        'Female', 'Female', 'Female', 'Female', 'Female', 'Male', 'Female',
#        'Female', 'Female', 'Female', 'Male', 'Female', 'Male', 'Male',
#        'Female', 'Female', 'Female', 'Female', 'Male', 'Female', 'Male',
#        'Female', 'Male', 'Female', 'Female', 'Male', 'Female', 'Female',
#        'Female', 'Female', 'Female', 'Female', 'Female', 'Female',
#        'Female', 'Female', 'Female', 'Female', 'Female', 'Male', 'Female',
#        'Female', 'Female', 'Male', 'Female', 'Female', 'Female', 'Female',
#        'Female', 'Male', 'Female', 'Male', 'Female', 'Female', 'Male',
# ...

# %%
y_predl = model_newl.predict(X)
y_predl
# Out:
# array(['Female', 'Female', 'Female', 'Male', 'Male', 'Male', 'Female',
#        'Male', 'Female', 'Female', 'Female', 'Male', 'Female', 'Female',
#        'Female', 'Female', 'Female', 'Female', 'Female', 'Female',
#        'Female', 'Female', 'Female', 'Male', 'Female', 'Female', 'Female',
#        'Female', 'Female', 'Female', 'Female', 'Female', 'Female',
#        'Female', 'Female', 'Male', 'Female', 'Female', 'Female', 'Male',
#        'Female', 'Female', 'Female', 'Female', 'Male', 'Female', 'Female',
#        'Male', 'Male', 'Female', 'Female', 'Female', 'Male', 'Female',
#        'Male', 'Female', 'Male', 'Male', 'Female', 'Male', 'Female',
#        'Female', 'Female', 'Female', 'Female', 'Female', 'Female',
#        'Female', 'Female', 'Female', 'Female', 'Female', 'Male', 'Male',
#        'Female', 'Female', 'Female', 'Male', 'Male', 'Female', 'Female',
#        'Female', 'Female', 'Male', 'Female', 'Male', 'Female', 'Female',
# ...

# %%
#check accurcay
acs_gg = accuracy_score(Y,y_predg)
acs_gg
# Out:
# 0.5709969788519638

# %%
acs_ll = accuracy_score(Y,y_predl)
acs_ll
# Out:
# 0.5498489425981873

# %%
# the better result id in gussian model so we select the gussianNB model to predict the sex

# %%
#SVM
from sklearn.svm import SVC

# %%
#modle build
svc = SVC()
svc
# Out:
# SVC()

# %%
# fit model
svc.fit(X,Y)
# Out:
# SVC()

# %%
# predict the output
y_predsvc = svc.predict(X)
y_predsvc
# Out:
# array(['Female', 'Female', 'Female', 'Male', 'Male', 'Male', 'Female',
#        'Male', 'Female', 'Female', 'Female', 'Male', 'Female', 'Female',
#        'Female', 'Male', 'Female', 'Female', 'Female', 'Female', 'Female',
#        'Female', 'Female', 'Male', 'Female', 'Female', 'Female', 'Female',
#        'Male', 'Female', 'Female', 'Female', 'Female', 'Female', 'Female',
#        'Male', 'Female', 'Female', 'Female', 'Male', 'Female', 'Female',
#        'Female', 'Female', 'Male', 'Female', 'Male', 'Male', 'Male',
#        'Female', 'Female', 'Female', 'Male', 'Female', 'Male', 'Female',
#        'Male', 'Male', 'Female', 'Male', 'Female', 'Female', 'Female',
#        'Female', 'Female', 'Female', 'Female', 'Female', 'Female',
#        'Female', 'Female', 'Female', 'Male', 'Male', 'Female', 'Female',
#        'Female', 'Male', 'Male', 'Female', 'Female', 'Female', 'Female',
#        'Male', 'Female', 'Male', 'Female', 'Female', 'Male', 'Male',
# ...

# %%
#check accuracy
acs_svc = accuracy_score(Y,y_predsvc)
acs_svc
# Out:
# 0.5709969788519638
